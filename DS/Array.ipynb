# %% [markdown]
# Arrays

# %% [markdown]
# What is it? Linear data structure to hold homogenous items in contiguous memory locations.
# Type of DS: Linear
# Structure: Array elements and array index (usually starts at 0)
#
# Based on the language, the element consists of either the value or the reference to the memory location where the value is stored.
